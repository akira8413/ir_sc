# %%
import pandas as pd
import openpyxl

url="https://finance.yahoo.co.jp/stocks/ranking/dividendYield?market=all&term=daily"
df=pd.read_html(url)
df[0]
# Out:
#     順位                          名称・コード・市場           取引値     決算年月    1株配当  \
# 0    1                (株)商船三井9104東証PRM掲示板    3,17014:28  2023/03   550.0
# 1    2                日本郵船(株)9101東証PRM掲示板  2,966.514:28  2023/03   510.0
# 2    3          ＮＳユナイテッド海運(株)9110東証PRM掲示板    3,57014:27  2023/03   340.0
# 3    4        三井松島ホールディングス(株)1518東証PRM掲示板    2,90914:28  2023/03   270.0
# 4    5                 乾汽船(株)9308東証STD掲示板    1,91814:27  2023/03   173.0
# 5    6              石油資源開発(株)1662東証PRM掲示板    3,72514:27  2023/03   300.0
# 6    7                川崎汽船(株)9107東証PRM掲示板    2,67214:28  2023/03   200.0
# 7    8                西松建設(株)1820東証PRM掲示板    3,83014:27  2023/03   285.0
# 8    9            いちごオフィスリート投資法人8975東証掲示板   83,90014:27  2023/04  6048.0
# 9   10                     ＪＴ2914東証PRM掲示板    2,61114:28  2022/12   188.0
# 10  11              三ツ星ベルト(株)5192東証PRM掲示板    3,37514:28  2023/03   240.0
# 11  12               (株)有沢製作所5208東証PRM掲示板    1,28614:28  2023/03    90.0
# ...
